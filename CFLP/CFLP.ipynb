# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from IPython.display import Image
from scipy import stats
from gurobipy import Model, GRB, quicksum
# %matplotlib inline

# %%
# settings
sns.reset_orig
sns.set_style('darkgrid')
sns.set_palette('Set1')

np.set_printoptions(linewidth=200)

# %%
# display the variables
Image(filename='variables.png')

# %%
# display the model
Image(filename='model.png')

# %%
# import data
i_data = pd.read_excel('data.xlsx', sheet_name='i_data')
j_data = pd.read_excel('data.xlsx', sheet_name='j_data')
dist_ij = pd.read_excel('data.xlsx', sheet_name='dist_ij').values

# %%
# declare the parameters and sets
h = i_data['Demand'].values
f = j_data['Fixed Charge'].values
v = j_data['Capacity'].values

I = [i for i in range(len(h))]
J = [j for j in range(len(f))]
A = [(i, j) for i in I for j in J]

c = {(i, j): dist_ij[i, j] for (i, j) in A}

a = 0.3

# %%
# create model
mdl = Model('CFLP')
# Out:
# Academic license - for non-commercial use only - expires 2022-08-28
# Using license file C:\Users\jack4\gurobi.lic

# %%
# add model variables
x = mdl.addVars(J, vtype=GRB.BINARY)
y = mdl.addVars(A, vtype=GRB.BINARY)

# %%
# add objective function
mdl.ModelSense = GRB.MINIMIZE
mdl.setObjective(quicksum(f[j]*x[j] for j in J) + a * quicksum(h[i]*c[i,j]*y[i,j] for i,j in A))

# %%
# add the model constraints
mdl.addConstrs(quicksum(y[i,j] for j in J) == 1 for i in I)
mdl.addConstrs(y[i,j] <= x[j] for i,j in A)
mdl.addConstrs(quicksum(h[i]*y[i,j] for i in I) <= v[j] for j in J)
mdl.update()

# %%
# %%time

# optimize
mdl.optimize()
# Out:
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
# Optimize a model with 2120 rows, 2020 columns and 8000 nonzeros
# Model fingerprint: 0xa14b80f0
# Variable types: 0 continuous, 2020 integer (2020 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [1e+01, 1e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Found heuristic solution: objective 379917.21578
# Presolve time: 0.01s
# Presolved: 2120 rows, 2020 columns, 8000 nonzeros
# Variable types: 0 continuous, 2020 integer (2020 binary)
#
# Root relaxation: objective 1.875310e+05, 1568 iterations, 0.05 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 187531.008    0  805 379917.216 187531.008  50.6%     -    0s
# H    0     0                    329586.64529 187531.008  43.1%     -    0s
# H    0     0                    251534.84342 187531.008  25.4%     -    0s
# H    0     0                    248682.36735 187531.008  24.6%     -    0s
# H    0     0                    248323.94181 187532.141  24.5%     -    0s
#      0     0 195552.857    0  571 248323.942 195552.857  21.3%     -    0s
# H    0     0                    246374.16944 195552.857  20.6%     -    0s
# H    0     0                    246286.65743 195552.857  20.6%     -    0s
# H    0     0                    246234.17575 195552.857  20.6%     -    0s
# H    0     0                    244478.88514 195552.857  20.0%     -    0s
# H    0     0                    244443.71975 195552.857  20.0%     -    0s
#      0     0 198066.390    0  614 244443.720 198066.390  19.0%     -    0s
#      0     0 201917.474    0  582 244443.720 201917.474  17.4%     -    0s
# H    0     0                    243998.48395 201917.474  17.2%     -    0s
# H44085 17874                    234230.19820 234154.865  0.03%   5.3    7s
# H44087 16981                    234226.95992 234155.710  0.03%   5.3    7s
# H44173 16201                    234213.26069 234155.902  0.02%   5.3    8s
# H44454 15872                    234209.17872 234156.809  0.02%   5.3    8s
# H44532 15080                    234209.15831 234156.809  0.02%   5.3    8s
# H46454 15261                    234201.11311 234156.869  0.02%   5.2    8s
# H46751 15512                    234199.87702 234156.869  0.02%   5.2    8s
# H46848 14733                    234195.50408 234157.138  0.02%   5.2    8s
# H46941 14069                    234195.01729 234157.138  0.02%   5.2    8s
# H47056 13402                    234193.70874 234157.138  0.02%   5.2    8s
# H47196 12763                    234192.45427 234157.138  0.02%   5.2    8s
# H47870 11988                    234191.75785 234157.138  0.01%   5.2    8s
# H63504 16574                    234188.71429 234159.401  0.01%   4.8    8s
# H63858 15687                    234187.29518 234159.401  0.01%   4.8    8s
# H66181 15311                    234186.55774 234159.560  0.01%   4.7    9s
# H66267 14619                    234186.01563 234159.635  0.01%   4.7    9s
#  78822 20688 234173.785   84   33 234186.016 234162.085  0.01%   4.6   10s
#
# Cutting planes:
#   Gomory: 48
#   Cover: 4
#   MIR: 21
#   StrongCG: 16
#   Flow cover: 10
#
# Explored 88083 nodes (396755 simplex iterations) in 11.25 seconds
# Thread count was 16 (of 16 available processors)
#
# Solution count 10: 234186 234187 234187 ... 234200
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.341860156301e+05, best bound 2.341640503135e+05, gap 0.0094%
# Wall time: 11.3 s

# %%
# opened locations and covered customers
opened = [j for j in J if x[j].X > 0.0]
covered = [a for a in A if y[a].X > 0.0]

# %%
# update the dataframes
i_data['Covered'] = [a[1] for a in A if y[a].X > 0.0]
j_data['Opened'] = [int(x[j].X > 0.0) for j in J]

# %%
# plot the station locations
fig, ax = plt.subplots(figsize=(10,10))
s = [100 if i == 1 else 50 for i in j_data['Opened'].values]
sns.scatterplot(x='X', y='Y', data=j_data, hue='Opened', palette=['grey', 'red'], style='Opened', markers=('X', '^'), s=s)
plt.title('Facilities Chosen')
# Out:
# Text(0.5, 1.0, 'Stations Chosen')

# %%
# plot the customer coverage
fig, ax = plt.subplots(figsize=(10,10))
sns.scatterplot(x='X', y='Y', data=i_data, size=1, legend=False, label="Customer")
sns.scatterplot(x='X', y='Y', data=j_data[j_data['Opened'] == 1], s=100, color='black', marker='^', label="Facility")
plt.title('Facility Coverage')
# Out:
# Text(0.5, 1.0, 'Facility Coverage')

# %%
# find objective value
fac_cost = sum([f[j]*x[j].X for j in J])
trans_cost = a * sum([h[i]*c[i,j] for i,j in covered])
obj_val = fac_cost + trans_cost

print('Facility cost = ', fac_cost)
print('Transportation cost = ', trans_cost)
print('Objective value = ', obj_val)
# Out:
# Facility cost =  59522.9749030783
# Transportation cost =  174663.04072706844
# Objective value =  234186.01563014672
